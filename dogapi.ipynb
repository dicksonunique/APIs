# %%
dic={'Dog1':"puppy",'dog2':"Bruno"}
for key,values in dic.items():
    print(key,values)
# Out:
# Dog1 puppy
# dog2 Bruno

# %%
from PIL import Image as img
import requests
from io import BytesIO
import json
dog_url='https://dog.ceo/api/breeds/image/random'
dogimg=json.loads(requests.get(dog_url).content)['message']
imgs=img.open(BytesIO(requests.get(dogimg).content))
display(imgs)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x252CE51C2E8>
